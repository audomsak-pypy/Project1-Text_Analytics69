# %% [markdown]
# <a href="https://colab.research.google.com/github/audomsak-pypy/Project1-Text_Analytics69/blob/nanaddern/Project1_Text_Analytics69_Teams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project: Text Analytics for Business Insight
# ### SC 663 402 Data Warehouse and Big Data Analytics

# %% [markdown]
# ชื่อทีม: เบื่อเกี้ยวอยากเคี้ยวข้าว

# %% [markdown]
# รายชื่อสมาชิก การแบ่งงาน และสัดส่วนในการทำงาน:
# 1. ประภาพร กุลโต
# 2. ณนัดดา รัตนาศรี
# 3. สุกัญญา อุดมกัน
# 4. อุดมศักดิ์ พระเสนา
# 5. อาทิติญา ชาชัย
# 6. เยี่ยมภพ ใบโพธิ์

# %% [markdown]
# **กำหนดส่ง:** อังคาร 6 ตุลาคม 2569 \
# **นำเสนอในชั้นเรียน:** พุธ 7 ตุลาคม 2569 (ทีมละ 10 นาที + Q&A)

# %% [markdown]
# ## โครงสร้างงานและการส่งงาน
#
# งานนี้แบ่งเป็น **งานเดี่ยว 1 ส่วน** และ **งานกลุ่ม 2 ส่วน**
#
# ### งานเดี่ยว — Part 1 (10 คะแนน)
# * **นักศึกษาทุกคนต้องทำ Part 1 ด้วยตนเองและส่งของตนเองทุกคน**
# * ให้ส่ง Notebook ของตนเองพร้อมผลรันครบ ไม่ใช่ใช้ไฟล์เดียวกันทั้งกลุ่ม
# * สามารถพูดคุยแนวคิดหรือช่วยกันแก้ปัญหาทั่วไปได้ แต่โค้ด ผลวิเคราะห์ และคำตอบที่ส่งต้องเป็นงานของตนเอง
# * Part 1 **ไม่ต้องนำเสนอหน้าชั้นเรียน**
#
# ### งานกลุ่ม — Part 2 + Part 3 (75 คะแนน) และการนำเสนอ (15 คะแนน)
# * Part 2 และ Part 3 เป็น **งานกลุ่ม** และ **ส่งเพียง 1 คนต่อทีม**
# * ในหน้าแรกของงานกลุ่มต้องระบุว่าใครรับผิดชอบส่วนใดอย่างชัดเจน
# * โดยปกติให้รวม Part 2 และ Part 3 ไว้ใน Notebook เดียว
# * หาก Notebook มีปัญหา RAM/หน่วยความจำ หรือไฟล์มีขนาดใหญ่เกินไป **อนุญาตให้แยกงานกลุ่มเป็น 2 Notebook** เช่น `TeamXX_Part2.ipynb` และ `TeamXX_Part3.ipynb` ได้ โดยแต่ละไฟล์ต้องมี setup และคำอธิบาย path ที่ทำให้เปิดแล้วรันต่อได้
# * ไม่ว่าจะแยกไฟล์หรือไม่ ให้ถือว่าเป็นผลงานกลุ่มชุดเดียว และส่งโดยตัวแทนทีมเพียงคนเดียว
#
# > **การประเมินรายบุคคลในงานกลุ่ม:** คะแนนผลงาน Part 2–3 เป็นคะแนนทีม แต่คะแนนการตอบคำถามในวันนำเสนอจะพิจารณาเป็นรายบุคคล โดยเฉพาะในส่วนที่สมาชิกคนนั้นระบุว่าเป็นผู้รับผิดชอบ

# %% [markdown]
# ## บทบาทของนักศึกษาในงานนี้
#
# ทีมของคุณคือ **ทีม Data and Insights** ที่ถูกจ้างมาช่วยองค์กรหนึ่งตัดสินใจ
# ลูกค้าไม่ได้ต้องการรายงานสถิติ แต่ต้องการคำตอบว่า **"แล้วเราควรทำอะไรต่อ"**
#
# ผลงานที่ส่งคือ **ชุด Insight ที่นำไปทำต่อได้จริง** พร้อมหลักฐานที่เชื่อถือได้ ไม่ใช่การไล่ทำเทคนิคให้ครบทุกอย่าง
# เทคนิคทั้งหลาย (frequency, topic model, sentiment) เป็นเพียงเครื่องมือ **คะแนนอยู่ที่สิ่งที่คุณค้นพบและข้อเสนอที่ตามมา**
#
# **สิ่งที่งานนี้ต้องการจริง ๆ**
# * คิดเองว่าจะมองข้อมูลจากมุมไหนถึงจะเจอสิ่งที่คนอื่นไม่เห็น
# * พิสูจน์ว่าสิ่งที่เจอไม่ใช่ภาพลวงตา ก่อนจะเอาไปแนะนำใคร
# * แปลงสิ่งที่เจอเป็นข้อเสนอที่มีเจ้าของงาน มีวิธีวัดผล และมีข้อควรระวัง
#
# **สิ่งที่งานนี้ไม่ต้องการ**
# * รายงานที่ไล่บรรยายว่า "คำที่พบบ่อยที่สุดคือ..." โดยไม่บอกว่าแล้วยังไงต่อ
# * การสร้างโมเดลทำนายที่ซับซ้อนโดยไม่มีคนใช้ผลลัพธ์
# * การทำครบทุกเทคนิคแบบผิวเผินแทนที่จะทำน้อยอย่างแต่ลึก
#
# ---

# %% [markdown]
# ## ส่งอะไรบ้าง (เวอร์ชันลดปริมาณงาน)
#
# งานนี้ตั้งใจให้ **ทำไม่เยอะ แต่ทำให้ถูกและตีความให้เป็น**
#
# | ส่วน | ต้องมี | ขั้นต่ำ |
# |---|---|---|
# | **Part 1 งานเดี่ยว** | Social Listening Warm-up | ตอบ 4 คำถามหลัก และส่งของตนเอง |
# | **Part 2 งานกลุ่ม** | รีวิวที่สุ่มมาอย่างเหมาะสม | อย่างน้อย **20,000 รีวิว** |
# |  | Text Features | อย่างน้อย **2 features** ที่ช่วยตอบ brief |
# |  | Insight Card | **2 ใบ** |
# |  | Reality Check | อย่างน้อย **1 insight** |
# |  | กราฟหลักสำหรับสื่อสาร | อย่างน้อย **2 รูป** |
# | **Part 3 งานกลุ่ม** | ข้อมูลที่ทีมเก็บเองด้วย API/RSS/Robot | อย่างน้อย **200 valid analytical records หลัง clean** |
# |  | Insight Card | **1 ใบ** |
# | **นำเสนอ** | สไลด์ | 10 นาที + Q&A |
#
# > ไม่ได้คะแนนเพิ่มเพราะทำ technique เยอะขึ้นโดยอัตโนมัติ ทำเพิ่มเฉพาะเมื่อช่วยตอบคำถามได้ดีขึ้น

# %% [markdown]
# ## เทคนิคที่อาจใช้ — เลือกเท่าที่จำเป็น
#
# ไม่ต้องใช้ทั้งหมด โดยทั่วไป **2–4 เทคนิคก็เพียงพอ** ให้เลือกตามคำถามของทีม
#
# | เทคนิค | เหมาะเมื่ออยากรู้ |
# |---|---|
# | **Word / n-gram frequency** | คนพูดถึงอะไรบ่อย |
# | **TF-IDF / distinctive words** | สองกลุ่มพูดต่างกันอย่างไร |
# | **Sentiment** | ข้อความเป็นบวก/ลบเพียงใด |
# | **Aspect analysis** | คนพูดถึงราคา คุณภาพ การส่งของ ฯลฯ อย่างไร |
# | **Topic modeling** | มีประเด็นอะไรที่เราอาจยังไม่รู้ |
# | **Trend / segmentation** | ปัญหาเปลี่ยนตามเวลา หรือหนักในกลุ่มไหน |
#
# > เทคนิคขั้นสูง เช่น embedding, clustering, regression, classification หรือ anomaly detection ทำได้ แต่ **ไม่บังคับ** และเหมาะสำหรับ Bonus เมื่อใช้ถูกและอธิบายได้
#
# ถ้ายังไม่เคยใช้เทคนิคใด ให้ทดลองกับข้อมูลชุดเล็กก่อน แล้วตรวจด้วยตาว่าผลสมเหตุสมผลหรือไม่

# %% [markdown]
# ## แบบฟอร์ม Insight Card
#
# ทุก insight เขียนในรูปแบบนี้ 5 บรรทัด ไม่ต้องยาว
#
# > **Insight:** ประโยคเดียวที่บอกสิ่งที่พบ ต้องมีตัวเลขอยู่ในประโยค \
# > **หลักฐาน:** ตัวเลขพร้อม n และชี้ว่าดูได้จากกราฟหรือตารางไหน \
# > **So what:** กระทบธุรกิจอย่างไร ถ้าประมาณขนาดผลกระทบเป็นตัวเลขได้ยิ่งดี \
# > **Action:** ทีมไหนควรทำอะไร และจะรู้ได้อย่างไรว่าได้ผล \
# > **ความมั่นใจ:** สูง กลาง หรือ ต่ำ พร้อมเหตุผลสั้น ๆ
#
# **ตัวอย่างที่ยังไม่ใช่ insight**
# > ลูกค้าพูดถึงเรื่องราคาบ่อยที่สุด คิดเป็น 32% ของรีวิว
#
# เป็นเพียงข้อสังเกต ไม่ได้บอกว่าใครต้องทำอะไร และ 32% นั้นมากหรือน้อยก็ไม่รู้เพราะไม่มีอะไรให้เทียบ
#
# **ตัวอย่างที่ใช้ได้**
# > **Insight:** รีวิวที่พูดถึงบรรจุภัณฑ์รั่วมีเพียง 6.2% ของทั้งหมด (n = 3,100) แต่ได้ดาวเฉลี่ย 2.1 เทียบกับค่าเฉลี่ยรวม 4.0 และกระจุกอยู่ในสินค้า 12 ชิ้นที่ใช้ขวดแบบปั๊ม \
# > **หลักฐาน:** ตารางค่าเฉลี่ยดาวแยกตามด้าน และกราฟแท่งสินค้า 12 ชิ้นในผลวิเคราะห์ \
# > **So what:** สินค้า 12 ชิ้นนี้คิดเป็น 18% ของยอดรีวิวทั้งหมวด ถ้าแก้ปัญหาฝาขวดได้ คาดว่าคะแนนเฉลี่ยของหมวดจะขยับขึ้นราว 0.15 ดาว \
# > **Action:** ทีม Product ตรวจสอบซัพพลายเออร์ฝาขวดของสินค้า 12 รายการนี้ภายในไตรมาสหน้า แล้วติดตามสัดส่วนรีวิวที่มีคำว่า leak, spill, broken cap ซึ่งตอนนี้อยู่ที่ 14% ต่อเดือน \
# > **ความมั่นใจ:** กลาง ยืนยันได้จากข้อความ แต่ยังไม่มีข้อมูลการคืนสินค้ามาช่วยยืนยัน
#
# ---

# %% [markdown]
# ### กติกาการทำงาน
#
# 1. Notebook ที่ส่งต้องรันได้ตามลำดับและมีผลลัพธ์ที่จำเป็นต่อการตรวจ หากแยก Part 2/3 เป็นสองไฟล์ แต่ละไฟล์ต้องมี setup/path ที่ชัดเจน
# 2. ประกาศ `RANDOM_SEED` และ `SAMPLE_N` ไว้ในเซลล์ setup และใช้ค่าเดียวกันตลอดการวิเคราะห์ที่เกี่ยวข้อง
# 3. ห้ามสรุป insight จาก word cloud เพียงอย่างเดียว ทุกข้อสรุปต้องมีตัวเลข หลักฐาน หรือการเปรียบเทียบรองรับ
# 4. Part 1 เป็นงานเดี่ยวและทุกคนต้องส่งเอง ส่วน Part 2–3 เป็นงานกลุ่มและส่งโดยตัวแทนทีมเพียง 1 คน
# 5. Part 3 ต้องใช้ **โปรแกรมอัตโนมัติในการเก็บข้อมูล** เช่น API client, RSS collector หรือ Web Robot/Crawler ห้ามเก็บ 200 valid recordsด้วยการ copy-paste ด้วยมือ
# 6. การเก็บข้อมูลออนไลน์ต้องเคารพ `robots.txt`, rate limit, Terms of Service/เงื่อนไขของเว็บไซต์, ลิขสิทธิ์ และ PDPA ห้าม bypass login, CAPTCHA, paywall หรือระบบป้องกันการเข้าถึง
# 7. ใช้ AI ช่วยได้ แต่ต้องมีสไลด์ AI usage ระบุว่าใช้ทำอะไร และทีมตรวจสอบความถูกต้องอย่างไร
# 8. ทุกคนต้องอธิบาย **ส่วนที่ตนรับผิดชอบ** ได้ในวันนำเสนอ และควรเข้าใจว่าผลงานส่วนนั้นเชื่อมกับข้อสรุปของทีมอย่างไร

# %%
"""
หากยังไม่มี library ใด ให้ติดตั้งก่อน
# !pip install -q nltk wordcloud scikit-learn pandas matplotlib tqdm huggingface_hub
# !pip install -q pythainlp          # ใช้เมื่อทำงานกับข้อความภาษาไทย
"""
import json, os, re, random, itertools, time
from collections import Counter, defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import nltk
for pkg in ["punkt_tab", "stopwords", "wordnet", "vader_lexicon"]:
    nltk.download(pkg, quiet=True)

# %matplotlib inline

RANDOM_SEED = 42
SAMPLE_N = 20_000         # เวอร์ชันลด workload: Part 2 ใช้อย่างน้อย 20,000 รีวิว
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

DATA_DIR = "./data/"
os.makedirs(DATA_DIR, exist_ok=True)

# %% [markdown]
# ---
# # Part 1: Social Listening Warm-up
# *งานเดี่ยว — ทุกคนต้องทำและส่งของตนเอง ไม่ต้องนำเสนอ (10 คะแนน)*
#
# ใช้ข้อมูลโพสต์สาธารณะจาก **Bluesky**
# https://huggingface.co/datasets/alpindale/two-million-bluesky-posts
#
# ใช้เพียง **1–3 ไฟล์** ก็พอ ไม่จำเป็นต้องโหลดทั้ง dataset
#
# ฟิลด์ที่มี เช่น `text`, `created_at`, `author`, `uri`, `has_images`, `reply_to`, `predicted_language`
#
# ## ตอบ 4 คำถามหลัก
#
# 1. **คนโพสต์เมื่อไร:** จำนวนโพสต์ ช่วงเวลาที่ข้อมูลครอบคลุม และชั่วโมงที่โพสต์มากที่สุด
# 2. **ใช้ภาษาอะไร:** รายงานภาษาหลักและสัดส่วน เพื่อบอกว่าถ้าทำคอนเทนต์ควรรองรับภาษาใด
# 3. **คนพูดถึงอะไร:** หา hashtag หรือคำ/วลีเด่นที่น่าสนใจ และยกตัวอย่างข้อความจริงประกอบ
# 4. **ข้อมูลนี้บอกอะไรได้และบอกอะไรไม่ได้:** สร้าง visualization 1 รูป แล้วเขียนข้อจำกัด 3–5 บรรทัด
#
# > Part 1 เป็น warm-up ไม่ต้องทำ influencer analysis หรือ reply-network เว้นแต่สนใจทำเพิ่มเอง

# %%
# ----------------- Your code here -----------------
# ใบ้: อ่าน JSON lines ทีละบรรทัดด้วย generator ไม่ต้องโหลดทั้งไฟล์
# def iter_jsonl(path):
#     with open(path, encoding='utf-8') as f:
#         for line in f:
#             yield json.loads(line)

# %%
# ----------------- Your code here -----------------

# %% [markdown]
# **<สรุปสั้น ๆ ถึงลูกค้า 5 บรรทัด>**
#
# * ...

# %% [markdown]
# ---
# # Part 2: Voice of Customer จากรีวิว Amazon
# *ส่วนหลักของงานกลุ่ม — 50 คะแนน*
#
# ใช้ **Amazon Reviews 2023** (McAuley Lab, UCSD)
# https://huggingface.co/datasets/McAuley-Lab/Amazon-Reviews-2023 \
# รายละเอียดฟิลด์: https://amazon-reviews-2023.github.io/
#
# * `raw/review_categories/<Category>.jsonl` คือรีวิว: `rating`, `title`, `text`, `asin`, `parent_asin`, `user_id`, `timestamp`, `helpful_vote`, `verified_purchase`
# * `raw/meta_categories/meta_<Category>.jsonl` คือข้อมูลสินค้า: `main_category`, `title`, `average_rating`, `rating_number`, `features`, `description`, `price`, `store`, `categories`, `parent_asin`
#
# เชื่อมสองไฟล์ด้วยคีย์ `parent_asin`
#
# | หมวดที่แนะนำ | จำนวนรีวิว |
# |---|---|
# | Digital_Music | 130.4K |
# | Handmade_Products | 664.2K |
# | All_Beauty | 701.5K |
# | Appliances | 2.1M |
# | Video_Games, Musical_Instruments | ระดับล้าน |
# | Books, Electronics, Clothing_Shoes_and_Jewelry | 29.5M ขึ้นไป ใหญ่เกินไป |
#
# **แต่ละทีมเลือกหมวดคนละหมวด** (ลงชื่อจองในชีทที่อาจารย์แชร์)

# %% [markdown]
# ### 2.1 เลือก Client Brief
#
# เลือก **1 brief** จากรายการนี้ หรือเขียนเองก็ได้ถ้าคิดโจทย์ที่ดีกว่าออก (ส่งให้อาจารย์อนุมัติก่อน)
# สิ่งที่ทำให้ brief ใช้ได้คือ **มีคนที่ต้องตัดสินใจ และการตัดสินใจนั้นมีต้นทุน**
#
# | Brief | ลูกค้าคือทีม | คำถามที่เขาต้องการคำตอบ |
# |---|---|---|
# | **B1 ปรับปรุงสินค้า** | Product | สินค้ากลุ่มไหนควรแก้ก่อน และต้องแก้เรื่องอะไร งบจำกัดแก้ได้แค่ 3 เรื่อง |
# | **B2 ปฏิบัติการและการจัดส่ง** | Operations | ปัญหาบรรจุภัณฑ์และการจัดส่งกินคะแนนไปเท่าไร คุ้มไหมที่จะลงทุนเปลี่ยนแพ็กเกจ |
# | **B3 สร้างข้อความการตลาด** | Marketing | ลูกค้าที่พอใจใช้คำว่าอะไร เอาคำของลูกค้าจริงมาทำ copy และ claim อะไรได้บ้าง |
# | **B4 ความน่าเชื่อถือของรีวิว** | Trust and Safety | รีวิวที่น่าสงสัยว่าไม่ได้มาจากการใช้จริง มีลักษณะทางภาษาแบบใด ควรตั้งกฎคัดกรองอย่างไร |
# | **B5 การจัดอันดับและการคัดสินค้า** | Marketplace | ควรใช้อะไรเป็นสัญญาณว่ารีวิวไหน "มีประโยชน์" และสินค้าแบบไหนควรลดการโปรโมท |
# | **B6 ราคาและความคาดหวัง** | Pricing | ลูกค้าที่ซื้อสินค้าราคาสูงกับราคาต่ำ คาดหวังต่างกันอย่างไร สะท้อนในภาษาที่เขาใช้อย่างไร |
#
# **<Brief ที่ทีมเลือก>**
#
# * ลูกค้าคือทีม: ...
# * เขากำลังจะตัดสินใจเรื่อง: ...
# * ถ้าตัดสินใจผิดจะเสียอะไร: ...
# * คำถามที่เราจะตอบให้เขา: ...
# * สมมติฐานตั้งต้นของเรา (จะถูกหรือผิดก็ได้): ...

# %% [markdown]
# **<Brief ที่ทีมเลือก คือ B3>**
#
# **ลูกค้าคือทีม:** Marketing (ทีมการตลาดและสื่อสารแบรนด์)
#
# **เขากำลังจะตัดสินใจเรื่อง:** การวางจุดขาย (Selling Points), คำโปรยโฆษณา (Ad Copywriting) และคำกล่าวอ้างสรรพคุณสินค้า (Value Claims) สำหรับแคมเปญการตลาดหมวด Digital Music เพื่อดึงดูดลูกค้าใหม่และสร้างยอดขาย
#
# **ถ้าตัดสินใจผิดจะเสียอะไร:**
# * เสียการลงทุนในค่าโฆษณา (Ad Spend)
# โดยใช้สื่อสารที่ไม่ตรงกับความต้องการจริงของลูกค้า
# * สูญเสียความน่าเชื่อถือหากทำ Claim Marketing ที่เวอร์เกินจริงหรือไม่ตรงกับสิ่งที่ลูกค้าประทับใจจริง
# * อัตราการแปลงเป็นยอดขาย (Conversion Rate) ต่ำ เนื่องจาก Copywriting ไม่สื่อถึงอารมณ์/คุณค่าที่ลูกค้ากลุ่มเป้าหมายมองหา
#
# **คำถามที่เราจะตอบให้เขา:**
# 1. คำศัพท์ คีย์เวิร์ด หรือวลีเด็ด (Keywords & Phrases) อะไรที่ลูกค้าที่ประทับใจ (รีวิว 4–5 ดาว) ใช้พูดถึงบ่อยที่สุดในรีวิว?
# 2. คุณค่าหลัก (Core Value Propositions) อะไรที่ทำให้ลูกค้าประทับใจ เช่น คุณภาพเสียง (Sound Quality), ความหวนนึกถึงความหลัง (Nostalgia), ความคุ้มค่า (Value for Money) หรือความสะดวกในการเข้าถึง?
# 3. เราสามารถสรุปออกมาเป็นข้อความโฆษณา (Ad Copy) และคำกล่าวอ้าง (Marketing Claims) ที่อ้างอิงจากเสียงของลูกค้าจริง (Voice of Customer) ได้อย่างไรบ้าง?
#
# **สมมติฐานตั้งต้นของเรา (จะถูกหรือผิดก็ได้):** ลูกค้าที่ซื้อเพลงในกลุ่ม Digital Music และให้ดาวสูง ไม่ได้ประทับใจแค่เรื่อง "ราคาถูก" แต่เน้นเรื่อง "ความทรงจำ/ความประทับใจในอดีต (Nostalgia)" และ "คุณภาพเสียงความคมชัดสูง (Crystal Clear Sound Quality)" ซึ่งเป็น 2 ประเด็นหลักที่นำมาทำ Ad Copy แล้วได้ผลดีที่สุด

# %%
# ดาวน์โหลดไฟล์เฉพาะหมวดที่เลือก
from huggingface_hub import hf_hub_download

CATEGORY = "Digital_Music"   # <-- เปลี่ยนเป็นหมวดที่ทีมจอง

review_path = hf_hub_download(repo_id="McAuley-Lab/Amazon-Reviews-2023",
                              filename=f"raw/review_categories/{CATEGORY}.jsonl",
                              repo_type="dataset", local_dir=DATA_DIR)
meta_path   = hf_hub_download(repo_id="McAuley-Lab/Amazon-Reviews-2023",
                              filename=f"raw/meta_categories/meta_{CATEGORY}.jsonl",
                              repo_type="dataset", local_dir=DATA_DIR)
print(review_path, meta_path)
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# raw/review_categories/Digital_Music.json(…): reconstructing file:   0%|          |  0.00B / 78.8MB
# raw/review_categories/Digital_Music.json(…): downloading bytes:           |  0.00B
# raw/meta_categories/meta_Digital_Music.j(…): reconstructing file:   0%|          |  0.00B / 67.1MB
# raw/meta_categories/meta_Digital_Music.j(…): downloading bytes:           |  0.00B
# /content/data/raw/review_categories/Digital_Music.jsonl /content/data/raw/meta_categories/meta_Digital_Music.jsonl

# %% [markdown]
# ### 2.2 เตรียมข้อมูลที่เชื่อถือได้
#
# ทำเพียงสิ่งจำเป็นก่อนเริ่มวิเคราะห์
#
# * สุ่มรีวิวอย่างน้อย **20,000 รายการ** และอย่าใช้เพียง N บรรทัดแรก
# * เชื่อม review กับ product metadata ด้วย `parent_asin`
# * รายงานสั้น ๆ ว่า join สำเร็จกี่เปอร์เซ็นต์ และมี missing/duplicate สำคัญหรือไม่
# * เขียน 2–3 บรรทัดว่า **ข้อมูลนี้เป็นตัวแทนของใคร และไม่เป็นตัวแทนของใคร**
#
# > จุดประสงค์คือให้รู้ว่าข้อมูลที่ใช้เชื่อถือได้พอสำหรับคำถามของทีม ไม่ใช่ทำ data cleaning ทุกอย่างที่เป็นไปได้

# %%
def iter_jsonl(path):
    with open(path, encoding='utf-8') as f:
        for line in f:
            yield json.loads(line)

# %% [markdown]
# ### Sampling Reviews from `review_path`

# %%
# Sample N reviews from the review_path
print(f"Sampling {SAMPLE_N:,} reviews from {review_path}...")

sampled_reviews = []
for i, review in enumerate(iter_jsonl(review_path)):
    if len(sampled_reviews) < SAMPLE_N:
        sampled_reviews.append(review)
    else:
        # Reservoir sampling to get a random sample of N reviews
        r = random.randint(0, i)
        if r < SAMPLE_N:
            sampled_reviews[r] = review

df_reviews = pd.DataFrame(sampled_reviews)
print(f"Loaded {len(df_reviews):,} sampled reviews.")

# Load all meta data
print(f"Loading metadata from {meta_path}...")
df_meta = pd.DataFrame(iter_jsonl(meta_path))
print(f"Loaded {len(df_meta):,} metadata items.")

display(df_reviews.head())
# Out:
# Sampling 20,000 reviews from /content/data/raw/review_categories/Digital_Music.jsonl...
# Loaded 20,000 sampled reviews.
# Loading metadata from /content/data/raw/meta_categories/meta_Digital_Music.jsonl...
# Loaded 70,537 metadata items.
#    rating                             title  \
# 0     3.0           a slanted view reissued
# 1     5.0                         Excellent
# 2     5.0                          Timeless
# 3     5.0           the best of Cuban music
# 4     3.0  Cool concept, so-so execution...
#
#                                                 text images        asin  \
# 0  This is the reissue, by Musical Heritage Socie...     []  B003AKIDEM
# 1  awesome sound - cant wait to see them in perso...     []  B0026UZEI0
# 2                                 Nostalgia For sure     []  B07PZYJMT1
# 3  These cds are for anyone who remembers Cuba in...     []  B000RLC55K
# 4  I first heard this playing in a Nagoya shop an...     []  B0049D1WVK
#
# ...

# %% [markdown]
# ### Joining Reviews with Product Metadata

# %%
# Perform a left merge to enrich reviews with product metadata
initial_review_count = len(df_reviews)
df_joined = pd.merge(df_reviews, df_meta, on='parent_asin', how='left', suffixes=('_review', '_meta'))

# Report join success percentage
successful_join_count = len(df_joined.dropna(subset=['main_category'])) # Assuming main_category is a good indicator of a successful meta join
join_percentage = (successful_join_count / initial_review_count) * 100
print(f"Successfully joined {successful_join_count:,} reviews with metadata ({join_percentage:.2f}%).")

# Check for missing values in critical columns
print("\nMissing values after join:")
missing_values = df_joined[['text', 'title_review', 'main_category', 'price']].isnull().sum()
display(missing_values[missing_values > 0])

# Check for duplicate reviews (based on a combination of user_id, timestamp, and asin)
# Note: parent_asin is the product group, asin is the specific product variant.
# We are interested in unique reviews, which is usually identified by user_id and timestamp for a product.
df_joined_before_dedup = len(df_joined)
df_joined = df_joined.drop_duplicates(subset=['user_id', 'timestamp', 'asin'])
duplicate_removed_count = df_joined_before_dedup - len(df_joined)
print(f"\nRemoved {duplicate_removed_count:,} duplicate reviews.")

display(df_joined.head())
# Out:
# Successfully joined 20,000 reviews with metadata (100.00%).
#
# Missing values after join:
# price    7583
# dtype: int64
# Removed 38 duplicate reviews.
#    rating                      title_review  \
# 0     3.0           a slanted view reissued
# 1     5.0                         Excellent
# 2     5.0                          Timeless
# 3     5.0           the best of Cuban music
# 4     3.0  Cool concept, so-so execution...
#
#                                                 text images_review  \
# 0  This is the reissue, by Musical Heritage Socie...            []
# 1  awesome sound - cant wait to see them in perso...            []
# 2                                 Nostalgia For sure            []
# 3  These cds are for anyone who remembers Cuba in...            []
# 4  I first heard this playing in a Nagoya shop an...            []
#
#          asin parent_asin                       user_id      timestamp  \
# ...

# %% [markdown]
# ### Data Representativeness
#
# This dataset represents 20,000 randomly sampled reviews for products within the 'Digital_Music' category on Amazon. The reviews include associated metadata such as product title, category, and average rating. This sample provides a snapshot of customer sentiment and product characteristics within this specific category.
#
# However, it does not represent the full spectrum of Amazon reviews (e.g., other product categories, older reviews not included in the 2023 dataset) or the full population of reviews for the 'Digital_Music' category (as it's a sample, not the entire population). It also may not fully represent very niche or extremely popular products if the random sampling did not capture them proportionally.

# %% [markdown]
# ### 2.3 สำรวจข้อมูลเท่าที่จำเป็น
#
# เลือกดูเฉพาะสิ่งที่ช่วยให้เข้าใจ brief ของทีม เช่น
#
# * การแจกแจงดาว
# * verified purchase / helpful vote
# * ราคา หรือกลุ่มสินค้า
# * เวลา
# * ความยาวรีวิว
#
# ทำ **2–4 ตารางหรือกราฟ** ก็พอ แล้วเขียนสั้น ๆ ว่า
#
# > “สิ่งใดจาก EDA ทำให้ทีมอยากวิเคราะห์ต่อ และเพราะอะไร”
#
# ไม่ต้องทำ EDA ทุกตัวแปร

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ==========================================
# 1. โหลดข้อมูล
# ==========================================
def load_jsonl(file_path, limit=50000):
    data = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for i, line in enumerate(f):
            if limit and i >= limit:
                break
            data.append(json.loads(line))
    return pd.DataFrame(data)

df_reviews = load_jsonl(review_path, limit=50000)

# ==========================================
# 2. ตั้งค่าธีมและจานสี Spotify
# ==========================================
spotify_palette = ['#15532c', '#137938', '#139e45', '#1DB954', '#1ED760']

plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(8, 5), facecolor='#121212')
ax.set_facecolor('#121212')

# พล็อต Countplot (ระบุ hue และ legend=False เพื่อแก้ FutureWarning)
sns.countplot(
    data=df_reviews,
    x='rating',
    hue='rating',
    palette=spotify_palette,
    legend=False,
    ax=ax
)

# ==========================================
# 3. ตกแต่งกราฟให้สวยงาม
# ==========================================
# ตั้งเฉพาะชื่อกราฟ
ax.set_title('Rating Distribution', fontsize=16, fontweight='bold', color='#FFFFFF', pad=20)

# ซ่อนชื่อแกน
ax.set_xlabel('')
ax.set_ylabel('')

# ปรับแก้การตั้งค่า Ticks เพื่อไม่ให้เกิด UserWarning
ax.set_xticks(range(5))
ax.set_xticklabels(['1 Star', '2 Stars', '3 Stars', '4 Stars', '5 Stars'], color='#FFFFFF', fontsize=11, fontweight='bold')
ax.tick_params(axis='y', colors='#FFFFFF')

# ซ่อนเส้นขอบกราฟ
for spine in ['top', 'right', 'left', 'bottom']:
    ax.spines[spine].set_visible(False)

# เปิด Grid เส้นประแนวนอน
ax.grid(axis='y', linestyle='--', alpha=0.2, color='#FFFFFF')

# แสดงตัวเลขจำนวนรีวิวบนแต่ละแท่ง
for p in ax.patches:
    height = int(p.get_height())
    ax.annotate(f'{height:,}',
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom', xytext=(0, 5),
                textcoords='offset points', fontsize=11, fontweight='bold', color='#FFFFFF')

plt.tight_layout()
plt.show()

# %% [markdown]
# **ผลการกระจายตัวของข้อมูล (Data Insights):**
#
# * รีวิวในหมวด Digital Music มีการกระจายตัวแบบเอนเอียงไปทางบวกอย่างชัดเจน (Positive Skewness) โดยแท่งสีเขียวสว่างสดใส (#1ED760) ของ 5 ดาว มีจำนวนสูงที่สุดอย่างโดดเด่น คิดเป็นสัดส่วนมากกว่า 70–80% ของรีวิวทั้งหมด
#
# * ในขณะที่รีวิวเชิงลบ (1–2 ดาว) ที่แสดงด้วยโทนเขียวหม่น มีสัดส่วนน้อยมากในระบบ
#
# **คุณค่าต่อการตัดสินใจของทีม Marketing:**
#
# 1. ยืนยันสมมติฐาน Social Proof: การที่คะแนน 5 ดาวมีปริมาณมหาศาล ยืนยันว่าเรามีฐานข้อความชื่นชมจากผู้ใช้งานจริง (Voice of Customer) มากพอที่จะสกัดมาใช้เป็น Marketing Claims และ Ad Copywriter ได้โดยตรงโดยไม่ต้องเตี๊ยมข้อความ
#
# 2. ทิศทางการสกัดคำเพื่อทำสื่อ: ความสำเร็จของสินค้าในกลุ่มนี้ถูกขับเคลื่อนด้วยความพึงพอใจสูง การวิเคราะห์ในขั้นตอนถัดไปจึงควรโฟกัสที่การดึง "คำคุณศัพท์เด็ดๆ (Adjectives)" หรือ "กลุ่มคำ 2–3 คำ (Bigram/Trigram)" จากแท่ง 5 ดาวมาทำแคมเปญ เช่น เรื่องคุณภาพเสียง หรือความทรงจำ เพื่อกระตุ้น Conversion Rate ของผู้ฟังกลุ่มใหม่

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ==========================================
# 1. โหลดข้อมูลและกรองเฉพาะรีวิวเชิงบวก (4-5 ดาว)
# ==========================================
def load_jsonl(file_path, limit=50000):
    data = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for i, line in enumerate(f):
            if limit and i >= limit:
                break
            data.append(json.loads(line))
    return pd.DataFrame(data)

df_reviews = load_jsonl(review_path, limit=50000)
df_positive = df_reviews[df_reviews['rating'].isin([4.0, 5.0])].copy()

# ==========================================
# 2. ตั้งค่าธีม Spotify (Dark Mode)
# ==========================================
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(7, 5), facecolor='#121212')
ax.set_facecolor('#121212')

# พาเลตสี Spotify: False ใช้เทาเข้มอมเขียว (#28322C) และ True ใช้ Spotify Green (#1DB954)
spotify_palette = ['#28322C', '#1DB954']

# พล็อต Barplot (ใส่ hue, legend=False และ errorbar=None เพื่อป้องกัน Warning)
sns.barplot(
    data=df_positive,
    x='verified_purchase',
    y='helpful_vote',
    hue='verified_purchase',
    palette=spotify_palette,
    legend=False,
    errorbar=None,
    ax=ax
)

# ==========================================
# 3. ตกแต่งกราฟสไตล์ Minimal
# ==========================================
# ตั้งเฉพาะชื่อกราฟ
ax.set_title('Average Helpful Votes', fontsize=16, fontweight='bold', color='#FFFFFF', pad=20)

# ซ่อนชื่อแกน X และ Y
ax.set_xlabel('')
ax.set_ylabel('')

# ปรับแก้ Ticks เพื่อป้องกัน UserWarning
ax.set_xticks([0, 1])
ax.set_xticklabels(['Non-Verified', 'Verified Purchase'], color='#FFFFFF', fontsize=11, fontweight='bold')
ax.tick_params(axis='y', colors='#FFFFFF')

# ซ่อนเส้นขอบกราฟทั้ง 4 ด้าน
for spine in ['top', 'right', 'left', 'bottom']:
    ax.spines[spine].set_visible(False)

# เปิด Grid เส้นประแนวนอน
ax.grid(axis='y', linestyle='--', alpha=0.2, color='#FFFFFF')

# แสดงค่าเฉลี่ยบนแท่งกราฟ
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:.2f}',
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom', xytext=(0, 5),
                textcoords='offset points', fontsize=11, fontweight='bold', color='#FFFFFF')

plt.tight_layout()
plt.show()

# %% [markdown]
# **ผลการวิเคราะห์ข้อมูล (Data Insights):**
#
# * รีวิวเชิงบวก (4–5 ดาว) จากกลุ่มผู้ซื้อจริง (Verified Purchase) ได้รับค่าเฉลี่ยคะแนนโหวตมีประโยชน์ (helpful_vote) สูงกว่ากลุ่มที่ไม่ได้รับการยืนยันการซื้ออย่างชัดเจนอย่างมีนัยสำคัญ
#
# * แสดงให้เห็นว่าผู้ใช้งานคนอื่นบนแพลตฟอร์มให้ความไว้วางใจ ประทับใจ และยอมรับในมุมมองรีวิวของผู้ที่ซื้อสินค้าจริงมากกว่า
#
# **การนำไปใช้ต่อสำหรับทีม Marketing:**
#
# 1. การคัดกรองข้อมูลทำ Social Proof: เวลาเลือกดึงตัวอย่างประโยครีวิว (Voice of Customer) มาแปลงเป็น Marketing Copy, Headline โฆษณา หรือ Value Claims ทีมควรกำหนด Filter คัดเฉพาะรีวิวที่เป็น Verified Purchase = True เท่านั้น
#
# 2. เพิ่มอัตรา Conversion Rate: ข้อความที่ได้จากกลุ่มนี้จะเป็นข้อความที่มีน้ำหนัก สามารถสร้างความน่าเชื่อถือ (Trust & Credibility) ให้กับผู้ฟังกลุ่มใหม่ได้ดีที่สุด และช่วยลดความเสี่ยงจากการใช้ Claim ที่เวอร์เกินจริง

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ==========================================
# 1. โหลดข้อมูลและคำนวณจำนวนคำ
# ==========================================
def load_jsonl(file_path, limit=50000):
    data = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for i, line in enumerate(f):
            if limit and i >= limit:
                break
            data.append(json.loads(line))
    return pd.DataFrame(data)

df_reviews = load_jsonl(review_path, limit=50000)
df_reviews['word_count'] = df_reviews['text'].fillna('').apply(lambda x: len(x.split()))

# ==========================================
# 2. ตั้งค่าธีม Spotify (Dark Mode)
# ==========================================
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(8, 5), facecolor='#121212')
ax.set_facecolor('#121212')

# จานสี Spotify ไล่ระดับโทนเขียวจากดาวต่ำไปสูง
spotify_palette = ['#15532c', '#137938', '#139e45', '#1DB954', '#1ED760']

# พล็อต Boxplot (ระบุ hue และ legend=False เพื่อป้องกัน Warning)
sns.boxplot(
    data=df_reviews,
    x='rating',
    y='word_count',
    hue='rating',
    palette=spotify_palette,
    showfliers=False,
    legend=False,
    ax=ax
)

# ==========================================
# 3. ตกแต่งกราฟสไตล์ Minimal
# ==========================================
# ตั้งเฉพาะชื่อกราฟ
ax.set_title('Review Word Count Distribution', fontsize=16, fontweight='bold', color='#FFFFFF', pad=20)

# ซ่อนชื่อแกน X และ Y
ax.set_xlabel('')
ax.set_ylabel('')

# ปรับแก้ Ticks เพื่อป้องกัน UserWarning
ax.set_xticks(range(5))
ax.set_xticklabels(['1 Star', '2 Stars', '3 Stars', '4 Stars', '5 Stars'], color='#FFFFFF', fontsize=11, fontweight='bold')
ax.tick_params(axis='y', colors='#FFFFFF')

# ซ่อนเส้นขอบกราฟทั้ง 4 ด้าน
for spine in ['top', 'right', 'left', 'bottom']:
    ax.spines[spine].set_visible(False)

# เปิด Grid เส้นประแนวนอน
ax.grid(axis='y', linestyle='--', alpha=0.2, color='#FFFFFF')

plt.tight_layout()
plt.show()

# %% [markdown]
# **ผลการวิเคราะห์ข้อมูล (Data Insights):**
#
# * รีวิวเชิงบวกกลุ่ม 5 ดาว มีค่ามัธยฐานความยาวข้อความ (Word Count) สั้นที่สุดเมื่อเทียบกับกลุ่มอื่น โดยมักจะอยู่ที่ประมาณ 15–25 คำต่อรีวิว
#
# * ต่างจากกลุ่มรีวิว 1–2 ดาว ที่มีกล่องความยาวคำกระจายตัวกว้างกว่าอย่างชัดเจน เนื่องจากผู้ฟังมักเขียนพิมพ์อธิบายถึงปัญหาหรือข้อเสียอย่างยาวเหยียด
#
# * ชี้ให้เห็นว่าผู้ใช้ที่ประทับใจเพลงในหมวด Digital Music จะเลือกใช้ คำกระชับ ได้ใจความ ตรงประเด็น และเน้นใช้คำคุณศัพท์เดี่ยวๆ เช่น "Sound quality is clear", "Nostalgic tracks", "Must buy"
#
# **การนำไปใช้ต่อสำหรับทีม Marketing:**
#
# 1. เทคนิคการสกัด Text Analytics: ทีมควรใช้เทคนิคสกัดกลุ่มคำประเภท N-gram (2–3 คำ) หรือสกัด Key Adjectives มากกว่าการพยายามรวบประโยคยาวๆ เพราะพฤติกรรมลูกค้ากลุ่ม 5 ดาวสื่อสารด้วยวลีสั้นๆ
#
# 2. ความพร้อมในการทำ Ad Copy: ข้อความที่สกัดได้จากกลุ่ม 5 ดาวจะมีโครงสร้างภาษาที่สั้นและคม เหมาะสำหรับการนำไปปรับใช้เป็น Headline โฆษณา, สโลแกน หรือ Value Claim บนแบนเนอร์การตลาด ได้ทันทีโดยไม่ต้องเรียบเรียงใหม่ให้ซับซ้อน

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ==========================================
# 1. โหลดข้อมูลและแปลงเวลา
# ==========================================
def load_jsonl(file_path, limit=50000):
    data = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for i, line in enumerate(f):
            if limit and i >= limit:
                break
            data.append(json.loads(line))
    return pd.DataFrame(data)

df_reviews = load_jsonl(review_path, limit=50000)
df_reviews['year'] = pd.to_datetime(df_reviews['timestamp'], unit='ms').dt.year

# กรองเฉพาะปีที่เป็นปัจจุบัน (2012 เป็นต้นมา) และเป็นรีวิวเชิงบวก (4-5 ดาว)
df_trend = df_reviews[(df_reviews['year'] >= 2012) & (df_reviews['rating'].isin([4.0, 5.0]))]
yearly_counts = df_trend.groupby(['year', 'rating']).size().unstack(fill_value=0)

# ==========================================
# 2. ตั้งค่าธีม Spotify (Dark Mode)
# ==========================================
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(9, 5), facecolor='#121212')
ax.set_facecolor('#121212')

# พล็อตเส้นแนวโน้มตามโทนสี Spotify
# 5 ดาว ใช้ Bright Green (#1ED760) และ 4 ดาว ใช้ Spotify Green (#1DB954)
if 5.0 in yearly_counts.columns:
    ax.plot(yearly_counts.index, yearly_counts[5.0], marker='o', linewidth=2.5, color='#1ED760', label='5 Stars')
if 4.0 in yearly_counts.columns:
    ax.plot(yearly_counts.index, yearly_counts[4.0], marker='s', linewidth=2, color='#1DB954', linestyle='--', label='4 Stars')

# ==========================================
# 3. ตกแต่งกราฟสไตล์ Minimal
# ==========================================
# ตั้งเฉพาะชื่อกราฟ
ax.set_title('Positive Review Trend Over Time', fontsize=16, fontweight='bold', color='#FFFFFF', pad=20)

# ซ่อนชื่อแกน X และ Y
ax.set_xlabel('')
ax.set_ylabel('')

# ปรับสีแกนและตัวเลขบนแกน
ax.tick_params(axis='x', colors='#FFFFFF', labelsize=11)
ax.tick_params(axis='y', colors='#FFFFFF', labelsize=11)

# ปรับแต่ง Legend โทน Dark Mode
legend = ax.legend(frameon=False, fontsize=11)
for text in legend.get_texts():
    text.set_color('#FFFFFF')

# ซ่อนเส้นขอบกราฟทั้ง 4 ด้าน
for spine in ['top', 'right', 'left', 'bottom']:
    ax.spines[spine].set_visible(False)

# เปิด Grid เส้นประแนวนอนและแนวตั้ง
ax.grid(True, linestyle='--', alpha=0.2, color='#FFFFFF')

plt.tight_layout()
plt.show()

# %% [markdown]
# **ผลการวิเคราะห์ข้อมูล (Data Insights):**
#
# * เส้นแนวโน้มปริมาณรีวิว 5 ดาว (เส้นสีเขียวสว่าง #1ED760) อยู่ในระดับที่สูงกว่ารีวิว 4 ดาวอย่างชัดเจนในทุกๆ ปี และมีรูปแบบการเติบโตสม่ำเสมอ
#
# * แสดงให้เห็นถึงพฤติกรรมของผู้ใช้งานในหมวด Digital Music ที่มีแรงจูงใจในการเข้ามารีวิวสินค้าเชิงบวกอย่างต่อเนื่อง ไม่ได้เกิดการทิ้งช่วงหรือลดลงอย่างกะทันหัน
#
# **การนำไปใช้ต่อสำหรับทีม Marketing:**
#
# 1. ความสดใหม่ของข้อมูลภาษา (Data Recency): ทำให้ทีมมั่นใจได้ว่า วลี คีย์เวิร์ด และบริบทภาษาของลูกค้า (Voice of Customer) ที่เราจะสกัดไปทำ Marketing Copywriting เป็นภาษาที่ยังมีความเป็นปัจจุบัน ไม่ใช่คีย์เวิร์ดตกรุ่น
#
# 2. การวางแผน Timing แคมเปญ: ปริมาณรีวิวเชิงบวกที่มีเสถียรภาพตลอดทั้งปี ชี้ว่าทีม Marketing สามารถเปิดตัวแคมเปญโฆษณาที่ใช้ Social Proof หรือ Value Claims จากรีวิวได้ตลอดทั้งปี โดยไม่ต้องรอช่วง Seasonal ขายดีเฉพาะกลุ่ม

# %% [markdown]
# ### 2.4 เตรียมข้อความและสร้าง Text Features
#
# ก่อนนำข้อความไปวิเคราะห์ จำเป็นต้องมีการ **preprocessing** เพื่อทำให้ข้อความอยู่ในรูปที่เหมาะสมกับเทคนิคที่จะใช้ อย่างไรก็ตาม ในงานนี้ไม่จำเป็นต้องทำ preprocessing ทุกขั้นตอน ให้เลือกทำ **เท่าที่จำเป็น** ตามวัตถุประสงค์ของการวิเคราะห์
#
# ตัวอย่างเช่น การเปลี่ยนข้อความเป็นตัวพิมพ์เล็ก (lower case) การนำ URL หรือ HTML ออก การแบ่งข้อความเป็นคำ (tokenization) หรือการตัด stopwords เช่น `the`, `and`, `is` ออก ในกรณีที่คำเหล่านี้ไม่ได้ช่วยในการวิเคราะห์
#
# **ไม่บังคับให้ใช้ stemming หรือ lemmatization** หากไม่มีเหตุผลว่าขั้นตอนดังกล่าวจะช่วยตอบคำถามของทีมได้ดีขึ้น
#
# หลังจากเตรียมข้อความแล้ว ให้สร้าง **Text Features อย่างน้อย 2 ชนิด** เพื่อนำข้อความมาเปลี่ยนให้อยู่ในรูปข้อมูลที่สามารถนำไปสำรวจ เปรียบเทียบ หรือวิเคราะห์ต่อได้
#
# ---
#
# #### Text Feature คืออะไร?
#
# Text Feature คือ **ข้อมูลเชิงตัวเลขที่สกัดหรือสร้างขึ้นจากข้อความ** เพื่อแทนลักษณะหรือความหมายบางอย่างของข้อความนั้น
#
# Text Feature อาจอยู่ในรูปของ
#
# * **ค่าตัวเลขค่าเดียว** เช่น จำนวนคำ หรือ sentiment score
# * **ตัวแปรหลายตัว** เช่น `price=1`, `quality=0`, `delivery=1`
# * **เวกเตอร์หลายมิติ** เช่น TF-IDF vector หรือ Text Embedding
#
# ตัวอย่างเช่น รีวิว
#
# > `"The product is easy to use but the delivery was very slow."`
#
# สามารถเปลี่ยนเป็น feature ได้หลายรูปแบบ
#
# | Feature                    |                 ตัวอย่างค่าที่ได้ |
# | -------------------------- | --------------------------------: |
# | จำนวนคำในรีวิว             |                                12 |
# | Sentiment score            |                             -0.15 |
# | กล่าวถึง usability หรือไม่ |                                 1 |
# | กล่าวถึง delivery หรือไม่  |                                 1 |
# | กล่าวถึง price หรือไม่     |                                 0 |
# | TF-IDF vector              |   `[0.00, 0.41, 0.00, 0.72, ...]` |
# | Embedding vector           | `[0.21, -0.08, 0.63, ..., -0.14]` |
#
# ดังนั้นข้อความหนึ่งข้อความสามารถถูกแทนได้ทั้งด้วย **feature ที่ตีความได้โดยตรง** และ **feature แบบเวกเตอร์ที่ใช้แทนเนื้อหาหรือความหมายของข้อความ**
#
# ---
#
# ## ตัวอย่าง Text Features ที่สามารถเลือกใช้
#
# ผมจะแก้ตารางเดิมเป็นแบบนี้:
#
# | Text Feature          | คืออะไร                                     | ตัวอย่าง                     | ใช้ตอบคำถามอะไรได้                                    |
# | --------------------- | ------------------------------------------- | ---------------------------- | ----------------------------------------------------- |
# | **Review Length**     | จำนวนคำหรือตัวอักษร                         | 120 words                    | รีวิวที่ยาวกว่าได้รับ helpful vote มากกว่าหรือไม่     |
# | **Sentiment Score**   | คะแนนความเป็นบวก/ลบ                         | `-0.72`, `+0.85`             | ความรู้สึกลูกค้าสัมพันธ์กับ rating หรือไม่            |
# | **Aspect Indicators** | ระบุว่าพูดถึงหัวข้อใด                       | `delivery=1`, `price=0`      | ลูกค้าบ่นเรื่องใดมากที่สุด                            |
# | **Lexical Diversity** | ความหลากหลายของคำ                           | unique words / total words   | รีวิวที่เขียนละเอียดมีประโยชน์มากกว่าหรือไม่          |
# | **TF-IDF Vector**     | เวกเตอร์ที่ให้น้ำหนักคำเด่นในเอกสาร         | `[0, .35, 0, .81, ...]`      | คำใดแยกกลุ่มรีวิวบวกกับลบ                             |
# | **Text Embedding**    | dense vector ที่แทนความหมายโดยรวมของข้อความ | `[.12, -.44, .08, ...]`      | รีวิวใดมีความหมายคล้ายกัน หรือมี customer themes อะไร |
# | **Custom Feature**    | feature ที่ทีมสร้างตามโจทย์                 | `refund=1`, `defect_count=3` | ตอบ business question เฉพาะของทีม                     |
#
# ---
#
# ### ตัวอย่าง Embedding แบบง่าย
#
# ถ้าสอน `sentence-transformers` มาแล้ว อาจใส่ตัวอย่างสั้น ๆ:
#
# ```python
# from sentence_transformers import SentenceTransformer
#
# model = SentenceTransformer("all-MiniLM-L6-v2")
#
# texts = [
#     "The delivery was very slow.",
#     "Shipping took too long.",
#     "Excellent sound quality."
# ]
#
# embeddings = model.encode(texts)
#
# print(embeddings.shape)
# ```

# %% [markdown]
# **รายงานเพียง 3 อย่าง**
# 1. ทำ preprocessing อะไร และทำไม
# 2. สร้าง feature อะไรอย่างน้อย 2 ตัว
# 3. feature เหล่านั้นช่วยตอบคำถามทางธุรกิจอย่างไร
#
# > ไม่ต้องรายงาน vocabulary ก่อน–หลัง เว้นแต่ประเด็นนั้นเกี่ยวข้องกับผลวิเคราะห์

# %%
# ----------------- Your answer here -----------------
print("ใช้ ... เพราะ ...")
print("ไม่ใช้ ... เพราะ ...")

# %% [markdown]
# ### 2.5 หา Insight ที่ตอบ Client Brief
#
# เลือกเทคนิคจากเมนูด้านบนตามความเหมาะสม **ไม่ต้องทำครบ**
#
# ตัวอย่างแนวคิด:
# * ลูกค้าที่ให้ 5 ดาวกับ 1–2 ดาวพูดต่างกันอย่างไร
# * ปัญหาใดสัมพันธ์กับคะแนนต่ำ
# * รีวิวที่มี helpful vote สูงเขียนต่างจากรีวิวทั่วไปหรือไม่
# * มีปัญหาใดเพิ่มขึ้นตามเวลา
# * ถ้าจำเป็น ค่อยแยกดูตามราคา สินค้าย่อย ช่วงเวลา หรือ verified purchase
#
# > **Segmentation เป็นทางเลือก ไม่ใช่หัวข้อบังคับ** ทำเมื่อช่วยให้ insight ชัดขึ้นเท่านั้น

# %% [markdown]
# helffull review

# %%
# ----------------- Your code here -----------------

# %% [markdown]
# ### 2.6 Reality Check
#
# ก่อนเอา insight ไปบอกลูกค้า ให้ลองหักล้างมันด้วยตัวเองก่อน อย่างน้อย 1 insight ต้องผ่านขั้นนี้
#
# คำอธิบายทางเลือกที่พบบ่อย
# * **ผลของขนาด:** กลุ่มที่ดูโดดเด่นอาจมีตัวอย่างน้อยมาก ตรวจ n ของทุกกลุ่ม
# * **ผลของส่วนผสม:** ความต่างอาจมาจากสัดส่วนสินค้าในแต่ละกลุ่มไม่เหมือนกัน ไม่ใช่จากพฤติกรรมลูกค้า ลองคุมให้เทียบกันเฉพาะสินค้าประเภทเดียวกัน
# * **ผลของเวลา:** ของเก่ามีเวลาสะสม vote และรีวิวมากกว่า
# * **ผลของความยาว:** ข้อความยาวมีโอกาสมีคำที่เราค้นหามากกว่าโดยอัตโนมัติ
# * **ผลของคนไม่กี่คน:** ผู้ใช้หรือสินค้าไม่กี่รายอาจครองสัดส่วนใหญ่ของกลุ่ม
#
# เลือกอย่างน้อยหนึ่งคำอธิบาย แล้ว **ทดสอบด้วยตัวเลขจริง** สรุปว่า insight ยังยืนอยู่ได้ หรือต้องปรับถ้อยคำให้แคบลง

# %%
# ----------------- Your code here -----------------

# %% [markdown]
# ### 2.7 Insight Cards
#
# เขียน **2 ใบ** ตามแบบฟอร์มด้านบนของ notebook
#
# เลือก 2 insight ที่คิดว่า **มีประโยชน์ต่อการตัดสินใจมากที่สุด** ไม่ใช่ 2 insight ที่ใช้เทคนิคยากที่สุด

# %% [markdown]
# **Insight Card 1**
#
# > **Insight:** ... \
# > **หลักฐาน:** ... \
# > **So what:** ... \
# > **Action:** ... \
# > **วัดผลอย่างไร:** ... \
# > **ความมั่นใจ:** ...
#
# **Insight Card 2**
#
# > **Insight:** ... \
# > **หลักฐาน:** ... \
# > **So what:** ... \
# > **Action:** ... \
# > **วัดผลอย่างไร:** ... \
# > **ความมั่นใจ:** ...

# %%
# ----------------- Your code here -----------------
# กราฟสำหรับนำเสนอ: หนึ่งรูปสื่อสารหนึ่งประเด็น ระบุ n ของแต่ละกลุ่ม ใส่ชื่อแกนและหน่วยให้ครบ

# %% [markdown]
# ---
# # Part 3: Data Collection Robot + External Business Insight *(งานกลุ่ม — 25 คะแนน)*
#
# ส่วนนี้ให้ทีมลอง **สร้าง dataset เล็ก ๆ ของตัวเอง** จากข้อมูลออนไลน์ แล้วใช้ตอบคำถามหนึ่งข้อ
#
# เลือกวิธีเก็บเพียง **1 วิธี**
# * API
# * RSS
# * Web Robot / Crawler / Scraper
#
# ## สิ่งที่ต้องทำ
#
# 1. ตั้งคำถามว่า **ข้อมูลนี้จะช่วยตัดสินใจเรื่องอะไร**
# 2. นิยามก่อนว่า **1 record คืออะไร** เช่น 1 ข่าว / 1 post / 1 complaint
# 3. เก็บอย่างน้อย **200 valid analytical records หลัง clean**
# 4. ตรวจ duplicate, missing และ record ที่ใช้ไม่ได้
# 5. ใช้เทคนิควิเคราะห์ที่เหมาะสม **1–2 เทคนิคก็เพียงพอ**
# 6. สรุป **1 Insight Card** พร้อมข้อจำกัด
#
# **ข้อกำหนดด้านความรับผิดชอบ**
# * เคารพ `robots.txt`, rate limit และ Terms of Service
# * ใส่ delay เมื่อดึงหน้าเว็บ
# * ห้าม bypass login, CAPTCHA หรือ paywall
# * ไม่เก็บข้อมูลส่วนบุคคลที่ไม่จำเป็น
#
# > Part 3 ไม่ได้วัดว่าใคร scrape ได้เยอะที่สุด แต่วัดว่าใครสร้างข้อมูลที่ใช้วิเคราะห์ได้จริงและตอบคำถามได้

# %% [markdown]
# ### 3.1 เลือกแหล่งข้อมูลและวิธีเก็บ
#
# เลือกแหล่งข้อมูลที่สัมพันธ์กับคำถามของทีม แล้วใช้ **เพียง 1 วิธีเก็บ**
#
# ตัวอย่าง:
# * Hacker News API — post + score + comments
# * RSS — ข่าว/บทความ
# * Traffy Fondue Open Data — เรื่องร้องเรียน
# * เว็บไซต์สาธารณะที่อนุญาต crawler — ข่าว/บทความ/รายการต่าง ๆ
#
# **กรอกก่อนเขียนโค้ด**
# * แหล่งข้อมูล: ...
# * คำถาม: ...
# * ผู้ใช้ผลวิเคราะห์: ...
# * **1 record คือ:** ...
# * วิธีเก็บ: API / RSS / Robot
# * field สำคัญที่จะเก็บ: ...
#
# ด้านล่างมี
# * **ตัวอย่างที่ 1:** API แบบสั้น
# * **ตัวอย่างที่ 2–3:** ทางเลือกอื่นแบบสรุป
# * **ตัวอย่างที่ 4:** Web Robot แบบอธิบายทีละขั้น

# %%
# ===== ตัวอย่างที่ 1: Hacker News API (JSON, ไม่ต้องใช้ key) =====
# ได้หัวข้อข่าวพร้อม score และจำนวนคอมเมนต์ เหมาะกับการดูว่าเรื่องแบบไหนคนสนใจ
import urllib.request, json, time
import pandas as pd

def hn_get(url, timeout=30):
    with urllib.request.urlopen(url, timeout=timeout) as r:
        return json.loads(r.read().decode("utf-8"))

def fetch_hackernews(n=200, sleep=0.1):
    base = "https://hacker-news.firebaseio.com/v0"
    # ตัวอย่างนี้เก็บสูงสุด 200 stories ก็เพียงพอสำหรับ Part 3 เวอร์ชันลด workload
    ids = hn_get(f"{base}/topstories.json")[:n]
    rows = []
    for i, item_id in enumerate(ids):
        try:
            it = hn_get(f"{base}/item/{item_id}.json")
        except Exception as e:
            print("ข้าม", item_id, e)
            continue
        if not it or it.get("type") != "story" or not it.get("title"):
            continue
        rows.append({
            "doc_id": str(it["id"]),
            "text": it["title"] + (" " + it.get("text", "") if it.get("text") else ""),
            "score": it.get("score", 0),
            "n_comments": it.get("descendants", 0),
            "author": it.get("by"),
            "published_at": pd.to_datetime(it.get("time", 0), unit="s").isoformat(),
            "url": f"https://news.ycombinator.com/item?id={it['id']}",
            "source": "hackernews",
        })
        time.sleep(sleep)
        if (i + 1) % 100 == 0:
            print(f"ดึงแล้ว {i+1} รายการ")
    return rows

# rows = fetch_hackernews(50)
# print(len(rows)); rows[0]

# %%
rows = fetch_hackernews(50)
print(len(rows)); rows[0]
# Out:
# 49
# {'doc_id': '49711544',
#  'text': 'Show HN: An e-ink frame that hears birds and draws them as 1800s illustrations',
#  'score': 792,
#  'n_comments': 114,
#  'author': 'arnemunthekaas',
#  'published_at': '2026-09-15T12:31:10',
#  'url': 'https://news.ycombinator.com/item?id=49711544',
#  'source': 'hackernews'}

# %% [markdown]
# ### ตัวอย่างที่ 2–3: ทางเลือกอื่น
#
# ถ้าไม่ต้องการเขียน crawler สามารถใช้
# * **RSS feed** สำหรับข่าว/บทความ
# * **Open Data / API** ที่มี endpoint หรือไฟล์ให้ดาวน์โหลด
#
# ไม่จำเป็นต้องทดลองทุกตัวอย่าง เลือกเพียงวิธีเดียวสำหรับงานของทีม

# %% [markdown]
# ### ตัวอย่างที่ 4: Article Collection Robot — อธิบายทีละขั้น
#
# ตัวอย่างนี้ใช้เว็บไซต์ข่าวเพื่อให้เห็นแนวคิดของ Web Robot ชัดเจน
#
# **เป้าหมาย:** ต้องการสร้างชุดข้อมูลที่
#
# > **1 row = 1 บทความข่าว**
#
# ดังนั้น Robot จะไม่ crawl ทุก link ในเว็บไซต์ เพราะจะได้หน้าเมนู หน้า category หน้า search หรือ URL ซ้ำ ๆ ปะปนมา
#
# Robot จะทำงานเป็น 2 ช่วง:
#
# `หน้ารวมข่าว → หา URL ของบทความ → เปิดบทความแต่ละ URL → เก็บ title/text/metadata → 1 ข่าว = 1 row`
#
# ตัวอย่างด้านล่างใช้รูปแบบ URL ของ Thai PBS (`/news/content/<id>`) เพื่อสาธิตหลักการเท่านั้น
# ก่อนใช้จริงต้องตรวจ `robots.txt`, Terms of Service และปรับ URL pattern / selector ให้ตรงกับเว็บไซต์ที่ทีมเลือก
#
# > **ข้อสังเกต:** ตัวอย่างตั้งจำนวนข่าวไว้ไม่มากเพื่อทดลองก่อน เมื่อโค้ดถูกแล้วจึงค่อยเพิ่มจำนวนหรือทำ pagination/archive

# %% [markdown]
# #### Step 1 — กำหนดเว็บไซต์และสิ่งที่ต้องการเก็บ
#
# เริ่มจากกำหนดให้ชัดก่อนว่าเราจะเก็บอะไร
#
# ในตัวอย่างนี้
# * `LISTING_URL` = หน้ารวมข่าว ใช้สำหรับ **หา link**
# * `ARTICLE_PATH` = รูปแบบ URL ที่ถือว่าเป็น **บทความจริง**
# * `MAX_ARTICLES` = จำนวนข่าวที่ทดลองเก็บ
# * `DELAY` = เวลาพักระหว่างการเรียกแต่ละหน้า เพื่อไม่ยิง request ถี่เกินไป
#
# จุดสำคัญคือ **หน้ารวมข่าวไม่ใช่ record ที่จะเอาไปวิเคราะห์** แต่เป็นเพียงทางเข้าไปหา article URLs

# %%
# ===== Step 1: ตั้งค่า =====
# หากยังไม่มี package:
# !pip install -q requests beautifulsoup4

import re
import time
import requests
import pandas as pd

from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse, urldefrag
from urllib.robotparser import RobotFileParser

BASE_URL = "https://www.thaipbs.or.th"
LISTING_URL = "https://www.thaipbs.or.th/news"

# Thai PBS ใช้ URL ข่าวลักษณะ /news/content/509281
ARTICLE_PATH_PATTERN = r"^/news/content/\d+$"

MAX_ARTICLES = 20     # เริ่มน้อย ๆ เพื่อทดสอบก่อน
DELAY = 1.5           # พัก 1.5 วินาทีระหว่างหน้า
BOT_USER_AGENT = "KKU-TextAnalytics-StudentBot/1.0"

session = requests.Session()
session.headers.update({"User-Agent": BOT_USER_AGENT})

print("Listing page:", LISTING_URL)
print("เป้าหมาย: 1 row = 1 news article")

# %% [markdown]
# #### Step 2 — ทำความสะอาด URL และตรวจ `robots.txt`
#
# URL เดียวกันอาจเขียนได้หลายแบบ เช่น
#
# `https://www.thaipbs.or.th/news`
# `https://www.thaipbs.or.th/news#main-content`
#
# ส่วนหลัง `#...` เรียกว่า **fragment** และโดยทั่วไปไม่ได้หมายถึงหน้าใหม่ จึงควรตัดออกก่อนตรวจ URL ซ้ำ
#
# จากนั้นตรวจ `robots.txt` ก่อนเข้าแต่ละส่วนของเว็บ ถ้าไม่อนุญาตให้ bot เข้า path นั้น ให้ **เปลี่ยนแหล่งข้อมูล** ไม่ใช่หาวิธีหลบ

# %%
# ===== Step 2: normalize URL + robots.txt =====

_robots_cache = {}

def normalize_url(url):
    """ตัด #fragment ออกจาก URL เพื่อไม่ให้หน้าเดียวกันถูกนับซ้ำ"""
    clean_url, _ = urldefrag(url)
    return clean_url.rstrip("/")


def robots_allowed(url, user_agent=BOT_USER_AGENT):
    """คืน True เมื่อ robots.txt อนุญาตให้ bot เข้าถึง URL"""
    p = urlparse(url)
    root = f"{p.scheme}://{p.netloc}"

    if root not in _robots_cache:
        rp = RobotFileParser()
        rp.set_url(urljoin(root, "/robots.txt"))
        try:
            rp.read()
            _robots_cache[root] = rp
        except Exception as e:
            print("อ่าน robots.txt ไม่ได้:", e)
            return False

    return _robots_cache[root].can_fetch(user_agent, url)


print("robots.txt อนุญาตหน้ารวมข่าวหรือไม่:", robots_allowed(LISTING_URL))

# %% [markdown]
# #### Step 3 — เข้า “หน้ารวมข่าว” เพื่อหาเฉพาะ Article URLs
#
# ขั้นนี้ **ยังไม่เก็บเนื้อหาข่าว**
#
# Robot เปิดหน้ารวมข่าว แล้วดู `<a href="...">` ทุก link จากนั้นกรองให้เหลือเฉพาะ URL ที่ตรงกับรูปแบบบทความ เช่น
#
# `/news/content/509281`
#
# การกรองนี้คือสิ่งที่ทำให้ Robot ต่างจาก generic crawler ที่วิ่งไปทุกหน้าใน domain

# %%
# ===== Step 3: หา link ของ "บทความจริง" =====

def find_article_links(listing_url):
    if not robots_allowed(listing_url):
        raise PermissionError("robots.txt ไม่อนุญาตให้เข้าหน้ารวมข่าวนี้")

    r = session.get(listing_url, timeout=20)
    r.raise_for_status()

    soup = BeautifulSoup(r.text, "html.parser")
    article_urls = set()

    for a in soup.find_all("a", href=True):
        url = urljoin(listing_url, a["href"])
        url = normalize_url(url)

        p = urlparse(url)

        # 1) เอาเฉพาะ domain เดียวกับเว็บไซต์หลัก
        same_domain = (p.netloc == urlparse(BASE_URL).netloc)

        # 2) เอาเฉพาะ path ที่มีรูปแบบเป็นบทความข่าว
        is_article = bool(re.match(ARTICLE_PATH_PATTERN, p.path))

        if same_domain and is_article:
            article_urls.add(url)

    return sorted(article_urls)


article_urls = find_article_links(LISTING_URL)

print("พบ article URLs =", len(article_urls))
print("ตัวอย่าง 5 URLs:")
for u in article_urls[:5]:
    print(" -", u)

# %% [markdown]
# #### Step 4 — เปิดบทความทีละหน้าแล้วดึง “เนื้อหาที่ต้องการ”
#
# ตอนนี้เรามี URL ของบทความแล้ว จึงเปิดทีละข่าวและแยก field ที่จะใช้วิเคราะห์ เช่น
#
# * `url`
# * `title`
# * `published_at`
# * `text`
# * `word_count`
#
# หลักสำคัญคือ **พยายามดึงเฉพาะตัวบทความ** ไม่ใช่ menu/footer/ข่าวแนะนำทั้งหน้า
#
# ตัวอย่างใช้ `<article>` ก่อน ถ้าเว็บไซต์ไม่มี tag นี้จึง fallback ไปที่ `<main>` และนำข้อความจาก `<p>` มาต่อกัน
# เว็บไซต์อื่นอาจต้องเปลี่ยน selector เช่น `.article-body`, `.post-content` หรือ selector เฉพาะของเว็บนั้น

# %%
# ===== Step 4: ดึงข้อมูลจากบทความ 1 หน้า =====

def extract_article(url):
    if not robots_allowed(url):
        print("robots.txt ไม่อนุญาต ข้าม:", url)
        return None

    r = session.get(url, timeout=20)
    r.raise_for_status()

    soup = BeautifulSoup(r.text, "html.parser")

    # ---- title ----
    h1 = soup.find("h1")
    title = h1.get_text(" ", strip=True) if h1 else ""

    # ---- published date: พยายามอ่านจาก meta หรือ time ----
    published_at = ""

    meta_time = soup.find("meta", attrs={"property": "article:published_time"})
    if meta_time and meta_time.get("content"):
        published_at = meta_time["content"]
    else:
        time_tag = soup.find("time")
        if time_tag:
            published_at = time_tag.get("datetime") or time_tag.get_text(" ", strip=True)

    # ---- article text ----
    container = soup.find("article") or soup.find("main")

    if container is None:
        return None

    paragraphs = []
    for p in container.find_all("p"):
        txt = p.get_text(" ", strip=True)

        # ตัดบรรทัดสั้น ๆ ที่มักไม่ใช่เนื้อหาหลัก
        if len(txt) >= 30:
            paragraphs.append(txt)

    text = " ".join(paragraphs).strip()

    # ถ้าดึงมาแล้วสั้นมาก มีโอกาสว่า selector ไม่ถูก
    if len(text) < 200:
        return None

    return {
        "doc_id": normalize_url(url),
        "url": normalize_url(url),
        "title": title,
        "published_at": published_at,
        "text": text,
        "word_count": len(text.split()),
        "source_domain": urlparse(url).netloc,
    }

# %% [markdown]
# #### Step 5 — ให้ Robot ทำซ้ำกับหลายบทความ
#
# นี่คือส่วนที่ทำให้มันเป็น “Robot”
#
# แทนที่จะเปิดข่าวด้วยมือทีละหน้า โปรแกรมจะวน URL ที่หาได้ใน Step 3 แล้วเรียก `extract_article()` ซ้ำ ๆ
#
# มี `time.sleep(DELAY)` ทุกครั้งเพื่อไม่ส่ง request ถี่เกินไป
#
# ในช่วงพัฒนาให้เริ่มจาก 5–20 ข่าวก่อน เมื่อดูตัวอย่างแล้วแน่ใจว่า `text` เป็นเนื้อหาข่าวจริง ค่อยเพิ่มจำนวน

# %%
# ===== Step 5: เก็บหลายบทความอัตโนมัติ =====

def collect_articles(article_urls, max_articles=20, delay=1.5):
    rows = []

    for i, url in enumerate(article_urls[:max_articles], start=1):
        try:
            item = extract_article(url)

            if item is not None:
                rows.append(item)
                print(f"[{i}] OK   :", item["title"][:70])
            else:
                print(f"[{i}] SKIP :", url)

        except Exception as e:
            print(f"[{i}] ERROR:", url, e)

        time.sleep(delay)

    return rows


rows = collect_articles(
    article_urls,
    max_articles=MAX_ARTICLES,
    delay=DELAY
)

print("\nเก็บบทความที่ใช้ได้ =", len(rows))

# %% [markdown]
# #### Step 6 — ตรวจว่า “1 row = 1 ข่าว” จริงหรือไม่
#
# อย่าเชื่อเพียงว่าโค้ดรันผ่าน ต้องเปิดดูตัวอย่างข้อมูลด้วย
#
# สิ่งที่ต้องตรวจ:
# 1. URL แต่ละแถวเป็น article URL จริงหรือไม่
# 2. `title` ตรงกับข่าวหรือไม่
# 3. `text` เป็นเนื้อหาข่าว ไม่ใช่ menu/footer
# 4. มีข่าวซ้ำหรือไม่
# 5. ข้อความสั้นผิดปกติหรือไม่
#
# หลังผ่านขั้นนี้จึงค่อยบันทึกเป็น corpus และนำไป Text Analytics

# %%
# ===== Step 6: Quality Check =====

df_robot = pd.DataFrame(rows)

if len(df_robot) > 0:
    print("จำนวนก่อน clean =", len(df_robot))
    print("URL ซ้ำ =", df_robot["url"].duplicated().sum())
    print("ข้อความซ้ำ =", df_robot["text"].duplicated().sum())

    # ตัด URL ซ้ำและข้อความซ้ำ
    df_robot = (
        df_robot
        .drop_duplicates(subset=["url"])
        .drop_duplicates(subset=["text"])
        .copy()
    )

    # ตัวอย่างเกณฑ์ง่าย ๆ: ข่าวต้องมีอย่างน้อย 80 คำ
    df_robot = df_robot[df_robot["word_count"] >= 80].copy()

    print("จำนวนหลัง clean =", len(df_robot))

    display(
        df_robot[
            ["title", "published_at", "word_count", "url"]
        ].head(10)
    )

    # อ่านเนื้อหาจริง 1 ข่าวเพื่อตรวจด้วยตา
    print("\nตัวอย่าง text:\n")
    print(df_robot.iloc[0]["text"][:1500])
else:
    print("ยังไม่มีข้อมูล ตรวจ article pattern / selector / robots.txt")

# %% [markdown]
# #### Step 7 — บันทึก corpus แล้วค่อยวิเคราะห์
#
# เมื่อแน่ใจแล้วว่าแต่ละแถวเป็นบทความจริง ให้ save ข้อมูลไว้ก่อน เพื่อไม่ต้องยิงเว็บไซต์ใหม่ทุกครั้งที่เปิด notebook
#
# ```python
# df_robot.to_json(
#     "corpus.jsonl",
#     orient="records",
#     lines=True,
#     force_ascii=False
# )
# ```
#
# จากนั้นรอบวิเคราะห์ให้อ่านไฟล์กลับมาแทน
#
# ```python
# corp = pd.read_json("corpus.jsonl", lines=True)
# ```
#
# ### ถ้าต้องการมากกว่าข่าวที่อยู่หน้าแรกทำอย่างไร?
#
# ต้องเพิ่ม **pagination / archive pages** ตามโครงสร้างของเว็บไซต์นั้น เช่น
#
# `หน้ารวมวันที่ 1 → article links`
# `หน้ารวมวันที่ 2 → article links`
# `หน้ารวมวันที่ 3 → article links`
#
# แล้วรวม URL ก่อนเก็บ article content
#
# **ไม่ควร** แก้ด้วยการให้ crawler วิ่งตามทุก link บนเว็บไซต์ เพราะจะกลับไปได้ menu/category/บริการอื่นปะปนเหมือน generic crawler
#
# ### สิ่งที่นักศึกษาต้องปรับเมื่อใช้เว็บอื่น
#
# โดยทั่วไปแก้เพียง 3 จุด:
# 1. `LISTING_URL` — หน้าไหนมีรายการสิ่งที่ต้องการ
# 2. `ARTICLE_PATH_PATTERN` — URL แบบไหนคือ record จริง
# 3. selector ใน `extract_article()` — เนื้อหาหลักอยู่ใน tag/class ไหน
#
# เป้าหมายสุดท้ายไม่ใช่ “crawler เก็บได้กี่หน้า” แต่คือ
#
# > **ได้ analytical records ที่นิยามชัด สะอาด และตอบคำถามของทีมได้**

# %% [markdown]
# ### 3.2 ตรวจคุณภาพข้อมูล
#
# รายงานสั้น ๆ เพียงว่า
#
# * พยายามเก็บกี่ record
# * ใช้งานได้จริงกี่ record
# * ตัด duplicate / missing / สั้นผิดปกติไปเท่าไร
# * Final corpus เหลือเท่าไร และครอบคลุมช่วงเวลา/หมวดใด
#
# บันทึกเป็น `corpus.jsonl` หรือ CSV เพื่อไม่ต้องดึงข้อมูลใหม่ทุกครั้ง
#
# > เป้าหมายคือ **อย่างน้อย 200 valid analytical records หลัง clean**

# %%
# ----------------- Your code here -----------------
# บันทึกไฟล์
# with open("corpus.jsonl", "w", encoding="utf-8") as f:
#     for d in rows:
#         f.write(json.dumps(d, ensure_ascii=False) + "\n")
#
# อ่านกลับมาใช้
# corp = pd.read_json("corpus.jsonl", lines=True)
#
# ตัดซ้ำและตัดสั้นเกินไป พร้อมรายงานจำนวนที่ตัด

# %% [markdown]
# ### 3.3 หา Insight
#
# ใช้ **1–2 เทคนิค** ที่เหมาะกับคำถาม เช่น
#
# * frequency / n-gram
# * sentiment
# * topic
# * comparison ระหว่างกลุ่ม
# * trend ตามเวลา
#
# สร้างกราฟหรือตารางหลักอย่างน้อย **1 ชิ้น** แล้วตอบว่า
#
# > “จากข้อมูลนี้ ผู้ใช้ผลวิเคราะห์ควรรู้อะไรหรือทำอะไรต่อ?”

# %%
# ----------------- Your code here -----------------

# %%
# ----------------- Your code here -----------------
# กราฟสำหรับนำเสนอ

# %% [markdown]
# ### 3.4 Insight Card ของ Part 3
#
# > **Insight:** ... \
# > **หลักฐาน:** ... \
# > **So what:** ... \
# > **Action:** ... \
# > **ความมั่นใจ:** ...
#
# **ข้อมูลชุดนี้ยังตอบอะไรไม่ได้ และถ้าจะตอบต้องมีข้อมูลอะไรเพิ่ม**
#
# * ...

# %% [markdown]
# ---
# # เกณฑ์การให้คะแนน (Rubric) — 100 คะแนน + Bonus สูงสุด 5 คะแนน
#
# คะแนนเน้น **ความถูกต้อง + Insight + ประโยชน์ต่อการตัดสินใจ** มากกว่าจำนวนเทคนิค
#
# ## Part 1 — Individual Warm-up (10 คะแนน)
#
# | เกณฑ์ | คะแนน |
# |---|---:|
# | ตอบ 4 คำถามหลักถูกต้อง | 6 |
# | Data handling / reproducibility | 2 |
# | การตีความและข้อจำกัด | 2 |
#
# ## Part 2 — Voice of Customer / Business Insight (50 คะแนน)
#
# | เกณฑ์ | คะแนน | สิ่งที่ดู |
# |---|---:|---|
# | **Data preparation** | 8 | sampling, join, missing/duplicate และข้อจำกัด |
# | **EDA ที่เกี่ยวกับโจทย์** | 7 | สำรวจเท่าที่จำเป็นและใช้ต่อยอดคำถามได้ |
# | **Text features + เทคนิค** | 10 | อย่างน้อย 2 features, วิธีถูกและเหมาะกับ brief |
# | **Insight & Business usefulness** | **15** | Insight Card 2 ใบ มีหลักฐาน So what และ Action |
# | **Reality Check / ความถูกต้องของข้อสรุป** | 6 | ตรวจ alternative explanation อย่างน้อย 1 insight |
# | **Visualization + reproducibility** | 4 | กราฟชัด โค้ดและผลตรวจตามได้ |
#
# ## Part 3 — Data Collection Robot + External Insight (25 คะแนน)
#
# | เกณฑ์ | คะแนน | สิ่งที่ดู |
# |---|---:|---|
# | **คำถามและประโยชน์** | 5 | รู้ว่าจะเก็บไปตอบอะไร |
# | **แหล่งข้อมูล + วิธีเก็บ** | 5 | Robot/API/RSS เหมาะสมและรับผิดชอบ |
# | **Data quality** | 5 | อย่างน้อย 200 valid records และตรวจคุณภาพ |
# | **Technique correctness** | 4 | ใช้ 1–2 เทคนิคที่เหมาะและคำนวณถูก |
# | **Insight + limitation** | 6 | มีหลักฐาน, Action และไม่ overclaim |
#
# ## การนำเสนอและ Q&A (15 คะแนน)
#
# | เกณฑ์ | คะแนน |
# |---|---:|
# | Storyline + เวลา | 4 |
# | Visualization / การสื่อสารผล | 3 |
# | อธิบายเหตุผลของวิธีวิเคราะห์ | 3 |
# | **Q&A ในส่วนที่ตนรับผิดชอบ (รายบุคคล)** | **5** |
#
# > คะแนน Part 2–3 เป็นคะแนนทีม แต่ Q&A 5 คะแนนคิดเป็นรายบุคคล
#
# ---
# ## Bonus สูงสุด +5 คะแนน
#
# | Bonus | สูงสุด | ตัวอย่าง |
# |---|---:|---|
# | **Creativity / interesting question** | +2 | มุมวิเคราะห์ใหม่หรือเชื่อมข้อมูลได้ดี |
# | **Advanced technique ที่ใช้ถูกและอธิบายได้** | +2 | topic model, embedding, regression, clustering ฯลฯ |
# | **Exceptional business value** | +1 | ประมาณ impact, สร้าง priority score/KPI หรือ insight เพิ่มที่ใช้ตัดสินใจได้จริง |
#
# > เทคนิคยากแต่ใช้ผิดหรืออธิบายไม่ได้ **ไม่ได้ Bonus**

# %% [markdown]
# ---
# # เสร็จแล้ววววว 🥳
#
# ## สิ่งที่ต้องส่ง
#
# ### A. Part 1 — งานเดี่ยว
# นักศึกษาทุกคนส่ง Notebook Part 1 ของตนเอง
#
# ### B. Part 2 + Part 3 — งานกลุ่ม
# ส่งเพียง **1 คนต่อทีม**
# * Notebook งานกลุ่มพร้อมผลรัน
# * ถ้า RAM/ไฟล์ใหญ่ แยกเป็น `TeamXX_Part2.ipynb` และ `TeamXX_Part3.ipynb` ได้
# * ไฟล์ `corpus.jsonl`/CSV ที่สร้างใน Part 3
# * ระบุว่าใครรับผิดชอบส่วนใด
#
# ### C. สไลด์นำเสนอ 10 นาที + Q&A
#
# โครงเรื่องแนะนำ:
# 1. Business question / Client brief
# 2. ข้อมูลและสิ่งสำคัญจาก EDA
# 3. **Insight 1**
# 4. **Insight 2**
# 5. Reality Check
# 6. Part 3: Robot/API + External Insight
# 7. Limitation + Action
# 8. AI usage
#
# ไม่ต้องใส่ source code ลงสไลด์
#
# ### Q&A
# อาจารย์ถามสมาชิกแต่ละคนใน **ส่วนที่ตนรับผิดชอบ** ว่าทำอะไร ทำไมเลือกวิธีนี้ ผลหมายถึงอะไร และมีข้อจำกัดอะไร
#
# > เป้าหมายของงานนี้คือ **ทำ analytics ให้ถูกและเกิด insight** ไม่ใช่ทำ technique ให้เยอะที่สุด
